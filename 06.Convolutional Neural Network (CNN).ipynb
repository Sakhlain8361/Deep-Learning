# %% [markdown]
# # Convolutional Neural Networks (CNNs)

# %% [markdown]
# - Convolutional Neural Networks (CNNs) are a specialized class of neural networks designed to process grid-like data, such as images. They are particularly well-suited for image recognition and processing tasks.
#
# - They are inspired by the visual processing mechanisms in the human brain, CNNs excel at capturing hierarchical patterns and spatial dependencies within images.
#
# - Convolutional Neural Networks (CNNs), also known as ConvNets, are a powerful type of deep learning architecture specifically designed for image, video, and signal processing tasks.
#
# - Unlike traditional neural networks that work with fully connected layers, CNNs leverage a special structure inspired by the human visual cortex.
#
# - This structure allows them to excel at extracting features and patterns from data with a grid-like structure, making them ideal for computer vision applications.

# %% [markdown]
# ![1_vkQ0hXDaQv57sALXAJquxA.webp](attachment:8c4ebcda-930d-4c35-ae64-69d9ad166ae7.webp)

# %% [markdown]
# Artificial Intelligence has been witnessing monumental growth in bridging the gap between the capabilities of humans and machines. Researchers and enthusiasts alike, work on numerous aspects of the field to make amazing things happen. One of many such areas is the domain of Computer Vision.
#
# The agenda for this field is to enable machines to view the world as humans do, perceive it in a similar manner, and even use the knowledge for a multitude of tasks such as Image & Video recognition, Image Analysis & Classification, Media Recreation, Recommendation Systems, Natural Language Processing, etc. The advancements in Computer Vision with Deep Learning have been constructed and perfected with time, primarily over one particular algorithm — a **Convolutional Neural Network**.

# %% [markdown]
# ## Key Components

# %% [markdown]
# - 1. **Convolutional Layers**: These layers apply convolutional operations to input images, using filters (also known as kernels) to detect features such as edges, textures, and more complex patterns. Convolutional operations help preserve the spatial relationships between pixels.
#
# - 2. **Pooling Layers**: They downsample the spatial dimensions of the input, reducing the computational complexity and the number of parameters in the network. Max pooling is a common pooling operation, selecting the maximum value from a group of neighboring pixels.
#
# - 3. **Activation Functions**: They introduce non-linearity to the model, allowing it to learn more complex relationships in the data.
#
# - 4. **Fully Connected Layers**: These layers are responsible for making predictions based on the high-level features learned by the previous layers. They connect every neuron in one layer to every neuron in the next layer.

# %% [markdown]
# ## (CNN) — Architecture

# %% [markdown]
# ![1_uAeANQIOQPqWZnnuH-VEyw.webp](attachment:348f7a2b-101b-45d5-bd10-2c14596f1930.webp)

# %% [markdown]
# ![download.png](attachment:4e812aff-cdc4-4216-bc4c-8d1a0a6caef5.png)

# %% [markdown]
# A **Convolutional Neural Network (ConvNet/CNN)** is a Deep Learning algorithm that can take in an input image, assign importance (learnable weights and biases) to various aspects/objects in the image, and be able to differentiate one from the other. The pre-processing required in a ConvNet is much lower as compared to other classification algorithms. While in primitive methods filters are hand-engineered, with enough training, ConvNets have the ability to learn these filters/characteristics.
#
# The architecture of a ConvNet is analogous to that of the connectivity pattern of Neurons in the Human Brain and was inspired by the organization of the Visual Cortex. Individual neurons respond to stimuli only in a restricted region of the visual field known as the Receptive Field. A collection of such fields overlap to cover the entire visual area.

# %% [markdown]
# ## How Does CNN work?

# %% [markdown]
# ![download.png](attachment:ae30c59e-3837-42e8-88a0-f79d92c8c4aa.png)

# %% [markdown]
# - 1. **Input Image**: The CNN receives an input image, which is typically preprocessed to ensure uniformity in size and format.
#
# - 2. **Convolutional Layers**: Filters are applied to the input image to extract features like edges, textures, and shapes.
#
# - 3. **Pooling Layers**: The feature maps generated by the convolutional layers are downsampled to reduce dimensionality.
#
# - 4. **Fully Connected Layers**: The downsampled feature maps are passed through fully connected layers to produce the final output, such as a classification label.
# Output: The CNN outputs a prediction, such as the class of the image.

# %% [markdown]
# ## Why ConvNets over Feed-Forward Neural Nets?

# %% [markdown]
# ![1_GLQjM9k0gZ14nYF0XmkRWQ.webp](attachment:85824b07-8166-4323-a5de-1d614942de45.webp)

# %% [markdown]
#       Flattening of a 3x3 image matrix into a 9x1 vector

# %% [markdown]
# An image is nothing but a matrix of pixel values, right? So why not just flatten the image (e.g. 3x3 image matrix into a 9x1 vector) and feed it to a Multi-Level Perceptron for classification purposes? Uh.. not really.
#
# In cases of extremely basic binary images, the method might show an average precision score while performing prediction of classes but would have little to no accuracy when it comes to complex images having pixel dependencies throughout.
#
# A ConvNet is able to **successfully capture the Spatial and Temporal dependencies** in an image through the application of relevant filters. The architecture performs a better fitting to the image dataset due to the reduction in the number of parameters involved and the reusability of weights. In other words, the network can be trained to understand the sophistication of the image better.

# %% [markdown]
# ## Input Image

# %% [markdown]
# ![1_15yDvGKV47a0nkf5qLKOOQ.webp](attachment:3d7354af-f66a-4fb9-a35a-87b879a9d160.webp)

# %% [markdown]
#             4x4x3 RGB Image

# %% [markdown]
# In the figure, we have an RGB image that has been separated by its three color planes — Red, Green, and Blue. There are a number of such color spaces in which images exist — Grayscale, RGB, HSV, CMYK, etc.
#
# You can imagine how computationally intensive things would get once the images reach dimensions, say 8K (7680×4320). The role of ConvNet is to reduce the images into a form that is easier to process, without losing features that are critical for getting a good prediction. This is important when we are to design an architecture that is not only good at learning features but also scalable to massive datasets.

# %% [markdown]
# ## Convolution Layer — The Kernel

# %% [markdown]
# ![1_GcI7G-JLAQiEoCON7xFbhg.gif](attachment:5c6ea8d3-783c-4c99-9b48-bd0251f8c1be.gif)

# %% [markdown]
#          Convoluting a 5x5x1 image with a 3x3x1 kernel to get a 3x3x1 convolved feature

# %% [markdown]
# Image Dimensions = 5 (Height) x 5 (Breadth) x 1 (Number of channels, eg. RGB)
#
# In the above demonstration, the green section resembles our **5x5x1 input image**, I. The element involved in the convolution operation in the first part of a Convolutional Layer is called the **Kernel/Filter, K**, represented in color yellow. We have selected **K as a 3x3x1 matrix**.

# %% [markdown]
# Kernel/Filter, K =
# $$
# K =
# \begin{bmatrix}
# 1 & 0 & 1 \\
# 0 & 1 & 0 \\
# 1 & 0 & 1
# \end{bmatrix}
# $$

# %% [markdown]
# The Kernel shifts 9 times because of **Stride Length = 1 (Non-Strided)**, every time performing an **elementwise multiplication operation (Hadamard Product) between K and the portion P of the image** over which the kernel is hovering.

# %% [markdown]
# ![1_NsiYxt8tPDQyjyH3C08PVA@2x.webp](attachment:71b7054e-ec84-4b6b-8c3a-728363e20b19.webp)

# %% [markdown]
#             Movement of the Kernel

# %% [markdown]
# The filter moves to the right with a certain Stride Value till it parses the complete width. Moving on, it hops down to the beginning (left) of the image with the same Stride Value and repeats the process until the entire image is traversed.

# %% [markdown]
# ![1_ciDgQEjViWLnCbmX-EeSrA.gif](attachment:bf91ba2a-998d-458c-92c9-e1576878faa6.gif)

# %% [markdown]
#        Convolution operation on a MxNx3 image matrix with a 3x3x3 Kernel

# %% [markdown]
# In the case of images with multiple channels (e.g. RGB), the Kernel has the same depth as that of the input image. Matrix Multiplication is performed between Kn and In stack ([K1, I1]; [K2, I2]; [K3, I3]) and all the results are summed with the bias to give us a squashed one-depth channel Convoluted Feature Output.

# %% [markdown]
# ![1_1VJDP6qDY9-ExTuQVEOlVg.gif](attachment:24f9e0e1-8248-4b17-abe2-b7f5fed3c2f3.gif)

# %% [markdown]
#       Convolution Operation with Stride Length = 2

# %% [markdown]
# The objective of the Convolution Operation is to **extract the high-level features** such as edges, from the input image. ConvNets need not be limited to only one Convolutional Layer. Conventionally, the first ConvLayer is responsible for capturing the Low-Level features such as edges, color, gradient orientation, etc. With added layers, the architecture adapts to the High-Level features as well, giving us a network that has a wholesome understanding of images in the dataset, similar to how we would.
#
# There are two types of results to the operation — one in which the convolved feature is reduced in dimensionality as compared to the input, and the other in which the dimensionality is either increased or remains the same. This is done by applying **Valid Padding** in the case of the former, or **Same Padding** in the case of the latter.

# %% [markdown]
# ![1_nYf_cUIHFEWU1JXGwnz-Ig.gif](attachment:80a8abfd-ad53-4333-953e-137aa40e1730.gif)

# %% [markdown]
#       SAME padding: 5x5x1 image is padded with 0s to create a 6x6x1 image

# %% [markdown]
# When we augment the 5x5x1 image into a 6x6x1 image and then apply the 3x3x1 kernel over it, we find that the convolved matrix turns out to be of dimensions 5x5x1. Hence the name — **Same Padding**.
#
# On the other hand, if we perform the same operation without padding, we are presented with a matrix that has dimensions of the Kernel (3x3x1) itself — **Valid Padding**.
#
# The following repository houses many such GIFs which would help you get a better understanding of how Padding and Stride Length work together to achieve results relevant to our needs.

# %% [markdown]
# ## Pooling Layer

# %% [markdown]
# ![1_uoWYsCV5vBU8SHFPAPao-w.gif](attachment:8712caf7-18d3-4253-8d48-b062fd97b5ce.gif)

# %% [markdown]
#       3x3 pooling over 5x5 convolved feature

# %% [markdown]
# Similar to the Convolutional Layer, the Pooling layer is responsible for reducing the spatial size of the Convolved Feature. This is to **decrease the computational power required to process the data** through dimensionality reduction. Furthermore, it is useful for **extracting dominant features** which are rotational and positional invariant, thus maintaining the process of effectively training the model.
#
# There are two types of Pooling: Max Pooling and Average Pooling. **Max Pooling** returns the **maximum value** from the portion of the image covered by the Kernel. On the other hand, **Average Pooling** returns the **average of all the values** from the portion of the image covered by the Kernel.
#
# Max Pooling also performs as a **Noise Suppressant**. It discards the noisy activations altogether and also performs de-noising along with dimensionality reduction. On the other hand, Average Pooling simply performs dimensionality reduction as a noise-suppressing mechanism. Hence, we can say that **Max Pooling performs a lot better than Average Pooling**.

# %% [markdown]
# ![1_KQIEqhxzICU7thjaQBfPBQ.webp](attachment:60cbbdc2-d27f-4521-b5a6-941e1d2d3970.webp)

# %% [markdown]
# The Convolutional Layer and the Pooling Layer, together form the i-th layer of a Convolutional Neural Network. Depending on the complexities in the images, the number of such layers may be increased for capturing low-level details even further, but at the cost of more computational power.
#
# After going through the above process, we have successfully enabled the model to understand the features. Moving on, we are going to flatten the final output and feed it to a regular Neural Network for classification purposes.

# %% [markdown]
# ## Classification — Fully Connected Layer (FC Layer)

# %% [markdown]
# ![1_kToStLowjokojIQ7pY2ynQ.webp](attachment:641edcf5-834b-4cf0-bcec-f6a46dbef615.webp)

# %% [markdown]
# Adding a Fully-Connected layer is a (usually) cheap way of learning non-linear combinations of the high-level features as represented by the output of the convolutional layer. The Fully-Connected layer is learning a possibly non-linear function in that space.
#
# Now that we have converted our input image into a suitable form for our Multi-Level Perceptron, we shall flatten the image into a column vector. The flattened output is fed to a feed-forward neural network and backpropagation is applied to every iteration of training. Over a series of epochs, the model is able to distinguish between dominating and certain low-level features in images and classify them using the **Softmax Classification** technique.
#
# There are various architectures of CNNs available which have been key in building algorithms which power and shall power AI as a whole in the foreseeable future. Some of them have been listed below:
#
# 1. LeNet
# 2. AlexNet
# 3. VGGNet
# 4. GoogLeNet
# 5. ResNet
# 6. ZFNet

# %% [markdown]
# ## Advantages

# %% [markdown]
# - **High accuracy at image recognition**: CNNs have achieved state-of-the-art performance in various image-related tasks such as object detection, segmentation, and classification.
# - **Weight sharing**: Unlike fully connected networks, CNNs use shared filters (kernels), reducing the number of parameters and improving computational efficiency.
# - **Minimizes computation**: Due to local connectivity and weight sharing, CNNs require fewer computations compared to traditional fully connected networks.
# - **Uses the same knowledge across all image locations**: The convolutional layers detect the same features (edges, textures, shapes) across different regions of an image.
# - **Ability to handle large datasets**: CNNs can process vast amounts of visual data, making them suitable for tasks like medical imaging, self-driving cars, and satellite imagery analysis.

# %% [markdown]
# ## Disadvantages

# %% [markdown]
# - **High computational requirements**: Training CNNs requires powerful GPUs or TPUs due to the complexity of convolution operations.
# - **Needs a large amount of labeled data**: CNNs typically require large datasets with labeled examples to achieve good performance.
# - **Large memory footprint**: Storing feature maps, weights, and activations consumes significant memory, making deployment challenging on low-resource devices.
# - **Training takes a long time**: Due to multiple layers and complex architectures, CNNs can take hours or even days to train, depending on the dataset size and hardware.

# %% [markdown]
# ## Application of CNN

# %% [markdown]
# ### 1. **Image Classification**
#    - Used in object recognition, scene classification, and medical diagnostics (e.g., detecting pneumonia in X-rays).
# ### 2. **Facial Recognition**
#    - Deployed in security systems, biometric authentication, and social media tagging.
# ### 3. **Video Analysis**
#    - Used in action recognition, surveillance systems, and motion tracking in sports.
# ### 4. **E-commerce**
#    - Helps in product recommendations based on visual similarity (e.g., suggesting fashion items based on user preferences).
# ### 5. **Recommendation Systems**
#    - Enhances content recommendation in streaming services by analyzing visual features.

# %% [markdown]
# # Implementing CNN in Python
#
# We will be using the **MNIST Digit Classification Dataset**, which we previously used in the **Practical Implementation of ANN**. Please refer to that first for a better understanding of CNN applications.
#
# ## 1.Importing Required Libraries

# %%
from tensorflow.keras.datasets import mnist
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D
from tensorflow.keras.layers import MaxPool2D
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import Dropout
from tensorflow.keras.layers import Dense

# %% [markdown]
# ## 2. Loading Data

# %%
(X_train, y_train), (X_test, y_test) = mnist.load_data()
# Out:
# ...
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 7s 1us/step

# %% [markdown]
# ## 3. Reshaping Data

# %%
X_train = X_train.reshape((X_train.shape[0], X_train.shape[1], X_train.shape[2], 1))
X_test = X_test.reshape((X_test.shape[0], X_test.shape[1], X_test.shape[2], 1))

# Checking the shape after reshaping
print(X_train.shape)
print(X_test.shape)
# Out:
# (60000, 28, 28, 1)
# (10000, 28, 28, 1)

# %%
import matplotlib.pyplot as plt

# Display 9 sample images from the dataset
fig, axes = plt.subplots(3, 3, figsize=(8, 8))

for i, ax in enumerate(axes.flat):
    ax.imshow(X_train[i].squeeze(), cmap='gray')  # Remove the extra dimension
    ax.set_title(f"Label: {y_train[i]}")
    ax.axis('off')

plt.tight_layout()
plt.show()

# %%
plt.imshow(X_train[0].squeeze(), cmap='gray')
plt.title(f"Label: {y_train[0]}")
plt.axis('off')
plt.show()

# %% [markdown]
# ## 4. Normalizing the Pixel Values

# %%
X_train = X_train / 255.0
X_test = X_test / 255.0

# %% [markdown]
# ## 5. Defining the CNN Model

# %%
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Input, Conv2D, MaxPool2D, Flatten, Dense

model = Sequential([
    Input(shape=(28, 28, 1)),  # Explicitly defining input layer
    Conv2D(32, (3, 3), activation='relu'),
    MaxPool2D(2, 2),
    Flatten(),
    Dense(100, activation='relu'),
    Dense(10, activation='softmax')
])

# %% [markdown]
# ## 6.Compiling the Model

# %%
model.compile(loss='sparse_categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# %% [markdown]
# ## 7.Training the Model

# %%
model.fit(X_train, y_train, epochs=10)
# Out:
# Epoch 1/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 28s 14ms/step - accuracy: 0.9018 - loss: 0.3266
# Epoch 2/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 24s 13ms/step - accuracy: 0.9838 - loss: 0.0543
# Epoch 3/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 24s 13ms/step - accuracy: 0.9894 - loss: 0.0340
# Epoch 4/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 24s 13ms/step - accuracy: 0.9929 - loss: 0.0231
# Epoch 5/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 24s 13ms/step - accuracy: 0.9951 - loss: 0.0154
# Epoch 6/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 24s 13ms/step - accuracy: 0.9972 - loss: 0.0101
# Epoch 7/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 24s 13ms/step - accuracy: 0.9977 - loss: 0.0078
# Epoch 8/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 24s 13ms/step - accuracy: 0.9986 - loss: 0.0054
# Epoch 9/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 24s 13ms/step - accuracy: 0.9982 - loss: 0.0056
# Epoch 10/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 23s 13ms/step - accuracy: 0.9980 - loss: 0.0058

# %% [markdown]
# ## 8.Evaluating the Model

# %%
model.evaluate(X_test, y_test)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9848 - loss: 0.0639
# [0.053773313760757446, 0.9871000051498413]
