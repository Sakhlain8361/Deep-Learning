# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns


from sklearn import preprocessing
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split


from keras.layers import Dense, BatchNormalization, Dropout
from keras.models import Sequential
from keras.utils import to_categorical
from keras import callbacks


from sklearn.metrics import precision_score, recall_score, confusion_matrix, classification_report, accuracy_score, f1_score

# %%
data = pd.read_csv(r"C:\Users\devad\Downloads\heart_failure_clinical_records_dataset.csv")
data
# Out:
#       age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 0    75.0        0                       582         0                 20
# 1    55.0        0                      7861         0                 38
# 2    65.0        0                       146         0                 20
# 3    50.0        1                       111         0                 20
# 4    65.0        1                       160         1                 20
# ..    ...      ...                       ...       ...                ...
# 294  62.0        0                        61         1                 38
# 295  55.0        0                      1820         0                 38
# 296  45.0        0                      2060         1                 60
# 297  45.0        0                      2413         0                 38
# 298  50.0        0                       196         0                 45
#
#      high_blood_pressure  platelets  serum_creatinine  serum_sodium  sex  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 299 entries, 0 to 298
# Data columns (total 13 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   age                       299 non-null    float64
#  1   anaemia                   299 non-null    int64
#  2   creatinine_phosphokinase  299 non-null    int64
#  3   diabetes                  299 non-null    int64
#  4   ejection_fraction         299 non-null    int64
#  5   high_blood_pressure       299 non-null    int64
#  6   platelets                 299 non-null    float64
#  7   serum_creatinine          299 non-null    float64
#  8   serum_sodium              299 non-null    int64
#  9   sex                       299 non-null    int64
#  10  smoking                   299 non-null    int64
#  11  time                      299 non-null    int64
#  12  DEATH_EVENT               299 non-null    int64
# dtypes: float64(3), int64(10)
# memory usage: 30.5 KB

# %%
#first of all let us evaluate the target and find out if our data is imbalanced or not
sns.countplot(x="DEATH_EVENT", hue="DEATH_EVENT", data=data, palette=cols, legend=False)
# Out:
# <Axes: xlabel='DEATH_EVENT', ylabel='count'>

# %%
#Examaning a corelation matrix of all the features 

# Define colormap
cmap = sns.diverging_palette(275, 150, s=80, l=55, n=9)

# Compute correlation matrix
corrmat = data.corr()

# Set figure size
plt.figure(figsize=(18, 18))

# Plot heatmap
sns.heatmap(corrmat, cmap=cmap, annot=True, square=True, fmt=".2f", linewidths=0.5)

# Show plot
plt.show()

# %%
#Evauating age distrivution 

# Set figure size
plt.figure(figsize=(20,12))

# Define only 2 colors for the DEATH_EVENT categories (0 and 1)
cols = ["#774571", "#b398af"]  # Adjusted to match two categories

# Plot age distribution with countplot
age_dist = sns.countplot(x="age", hue="DEATH_EVENT", data=data, palette=cols)

# Set title with custom color
age_dist.set_title("Distribution of Age", color="#773577", fontsize=16)

# Show plot
plt.show()

# %%
# Boxen and swarm plot of some non binary features.

# Define distinct colors for DEATH_EVENT categories
cols = ["#1f77b4", "#ff7f0e"]  # Blue & Orange for better visibility

# List of features to visualize
features = ["age", "creatinine_phosphokinase", "ejection_fraction", "platelets", 
            "serum_creatinine", "serum_sodium", "time"]

for i in features:
    plt.figure(figsize=(8, 8))

    # Swarm plot with GREEN dots to stand out
    sns.swarmplot(x=data["DEATH_EVENT"], y=data[i], color="green", alpha=0.6, size=3)

    # Boxen plot with distinct colors for each DEATH_EVENT category
    sns.boxenplot(x="DEATH_EVENT", y=i, data=data, hue="DEATH_EVENT", palette=cols, legend=False)

    plt.title(f"Distribution of {i} by DEATH_EVENT", fontsize=14, color="black")
    plt.show()

# %%
data.describe().T
# Out:
#                           count           mean           std      min  \
# age                       299.0      60.833893     11.894809     40.0
# anaemia                   299.0       0.431438      0.496107      0.0
# creatinine_phosphokinase  299.0     581.839465    970.287881     23.0
# diabetes                  299.0       0.418060      0.494067      0.0
# ejection_fraction         299.0      38.083612     11.834841     14.0
# high_blood_pressure       299.0       0.351171      0.478136      0.0
# platelets                 299.0  263358.029264  97804.236869  25100.0
# serum_creatinine          299.0       1.393880      1.034510      0.5
# serum_sodium              299.0     136.625418      4.412477    113.0
# sex                       299.0       0.648829      0.478136      0.0
# smoking                   299.0       0.321070      0.467670      0.0
# time                      299.0     130.260870     77.614208      4.0
# ...

# %%
#assigning values to features as X and target as y
X=data.drop(["DEATH_EVENT"],axis=1)
y=data["DEATH_EVENT"]

# %%
#Set up a standard scaler for the features
col_names = list(X.columns)
s_scaler = preprocessing.StandardScaler()
X_df= s_scaler.fit_transform(X)
X_df = pd.DataFrame(X_df, columns=col_names)   
X_df.describe().T
# Out:
#                           count          mean       std       min       25%  \
# age                       299.0  5.703353e-16  1.001676 -1.754448 -0.828124
# anaemia                   299.0  1.009969e-16  1.001676 -0.871105 -0.871105
# creatinine_phosphokinase  299.0  0.000000e+00  1.001676 -0.576918 -0.480393
# diabetes                  299.0  9.060014e-17  1.001676 -0.847579 -0.847579
# ejection_fraction         299.0 -3.267546e-17  1.001676 -2.038387 -0.684180
# high_blood_pressure       299.0  0.000000e+00  1.001676 -0.735688 -0.735688
# platelets                 299.0  7.723291e-17  1.001676 -2.440155 -0.520870
# serum_creatinine          299.0  1.425838e-16  1.001676 -0.865509 -0.478205
# serum_sodium              299.0 -8.673849e-16  1.001676 -5.363206 -0.595996
# sex                       299.0 -8.911489e-18  1.001676 -1.359272 -1.359272
# smoking                   299.0 -1.188199e-17  1.001676 -0.687682 -0.687682
# ...

# %%
#looking at the scaled features
# Generate a color palette that matches the number of columns in X_df
colours = sns.color_palette("Set2", n_colors=len(X_df.columns))

plt.figure(figsize=(20,10))

# Boxen plot with fixed palette size
sns.boxenplot(data=X_df, palette=colours)

plt.xticks(rotation=90)
plt.title("Scaled Feature Distributions", fontsize=14, color="black")
plt.show()

# %%
#spliting test and training sets
X_train, X_test, y_train,y_test = train_test_split(X_df,y,test_size=0.25,random_state=42)

# %%
early_stopping = callbacks.EarlyStopping(
    min_delta=0.001, # minimium amount of change to count as an improvement
    patience=20, # how many epochs to wait before stopping
    restore_best_weights=True)

# Initialising the NN
model = Sequential()

# layers
model.add(Dense(units = 16, kernel_initializer = 'uniform', activation = 'relu', input_dim = 12))
model.add(Dense(units = 8, kernel_initializer = 'uniform', activation = 'relu'))
model.add(Dropout(0.25))
model.add(Dense(units = 4, kernel_initializer = 'uniform', activation = 'relu'))
model.add(Dropout(0.5))
model.add(Dense(units = 1, kernel_initializer = 'uniform', activation = 'sigmoid'))
from keras.optimizers import SGD
# Compiling the ANN
model.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])

# Train the ANN
history = model.fit(X_train, y_train, batch_size = 32, epochs = 500,callbacks=[early_stopping], validation_split=0.2)
# Out:
# C:\Users\devad\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 5s 136ms/step - accuracy: 0.5987 - loss: 0.6929 - val_accuracy: 0.7556 - val_loss: 0.6916
# Epoch 2/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.7320 - loss: 0.6915 - val_accuracy: 0.7556 - val_loss: 0.6901
# Epoch 3/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.7355 - loss: 0.6901 - val_accuracy: 0.7556 - val_loss: 0.6886
# Epoch 4/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.7338 - loss: 0.6888 - val_accuracy: 0.7556 - val_loss: 0.6871
# Epoch 5/500
# ...

# %%
val_accuracy = np.mean(history.history['val_accuracy'])
print("\n%s: %.2f%%" % ('val_accuracy', val_accuracy*100))
# Out:
# val_accuracy: 75.78%

# %%
history_df = pd.DataFrame(history.history)

plt.plot(history_df.loc[:, ['loss']], "#6daa9f", label='Training loss')
plt.plot(history_df.loc[:, ['val_loss']],"#774571", label='Validation loss')
plt.title('Training and Validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend(loc="best")

plt.show()

# %%
history_df = pd.DataFrame(history.history)

plt.plot(history_df.loc[:, ['accuracy']], "#6daa9f", label='Training accuracy')
plt.plot(history_df.loc[:, ['val_accuracy']], "#774571", label='Validation accuracy')

plt.title('Training and Validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
# Predicting the test set results
y_pred = model.predict(X_test)
y_pred = (y_pred > 0.5)
np.set_printoptions()
# Out:
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step

# %%
# confusion matrix
cmap1 = sns.diverging_palette(275,150,  s=40, l=65, n=6)
plt.subplots(figsize=(12,8))
cf_matrix = confusion_matrix(y_test, y_pred)
sns.heatmap(cf_matrix/np.sum(cf_matrix), cmap = cmap1, annot = True, annot_kws = {'size':15})
# Out:
# <Axes: >

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.68      0.89      0.77        44
#            1       0.72      0.42      0.53        31
#
#     accuracy                           0.69        75
#    macro avg       0.70      0.65      0.65        75
# weighted avg       0.70      0.69      0.67        75
