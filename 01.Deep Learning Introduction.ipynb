# %% [markdown]
# ## Deep Learning

# %% [markdown]
# - Deep learning is a subset of machine learning that uses multi-layered neural networks, called deep neural networks, to simulate the complex decision-making power of the human brain.
#
# - Deep learning models are trained on large amounts of data, and they can learn to recognize complex patterns in that data.
#
# - This makes them well-suited for a variety of tasks, including image recognition, natural language processing, and speech recognition.

# %% [markdown]
# ![deeplearning.jpg](attachment:3608eb06-6747-4ebf-ad81-86bfdd1bfc4f.jpg)

# %% [markdown]
# ## How Does Deep Learning Work?

# %% [markdown]
# - Data Input
#
# - Neural Network Architecture
#
# - Learning Process (Training)
#
# - Backpropagation
#
# - Feature Extraction and Representation Learning
#
# - Prediction
#
# - Evaluation

# %% [markdown]
# ## Types of Deep Learning Layers

# %% [markdown]
# - The **input layer** of nodes receives the information and transfers it to the underlying nodes;here the network fixates on patterns of local contrast as important.
#
# - **Hidden layers** are the ones where the computations appear, this is the layer that uses those patterns of local contrast to fixate on things that resemble
#
# - In the **Output layer**, the results of the computations will show up. In this layer, the features will be applied to templates.

# %% [markdown]
# ![download.png](attachment:ebab1f77-1680-4e8a-8004-00365654b802.png)

# %% [markdown]
# ## Types of neural networks

# %% [markdown]
# - Perceptron
#
# - ANNs (Artificial Neural Networks)
#
# - CNNs (Convolutional Neural Networks)
#
# - RNNs (Recurrent Neural Networks)

# %% [markdown]
# ## Applications of Deep Learning

# %% [markdown]
# - Self-driving cars
#
# - Facial recognition
#
# - Fraud detection
#
# - Machine translation
#
# - Many more

# %% [markdown]
# ## Perceptron

# %% [markdown]
# ![img_neural_networks.jpg](attachment:e39053c6-53ea-443d-ac62-603b484b647f.jpg)

# %% [markdown]
# - A Perceptron is a neural network unit that does certain computations to detect features or business intelligence in the input data.
#
# - It is a function that maps its input “x,” which is multiplied by the learned weight coefficient, and generates an output value ”f(x).
#
# - Mr. Frank Rosenblatt invented the perceptron model as a binary classifier which contains three main components.

# %% [markdown]
# ![download.png](attachment:bef86a93-b2a3-460f-913e-0151384ca752.png)

# %% [markdown]
# ## Types of Perceptron Models

# %% [markdown]
# Based on the layers, Perceptron models are divided into two types. These are as follows:
#
# - Single-layer Perceptron Model
#
# - Multi-layer Perceptron model

# %% [markdown]
# ## Single Layer Perceptron Model

# %% [markdown]
# - A single-layered perceptron model consists feed-forward network and also includes a threshold transfer function inside the model.
#
# - The main objective of the single-layer perceptron model is to analyze the linearly separable objects with binary outcomes.
#
# - "Single-layer perceptron can learn only linearly separable patterns."

# %% [markdown]
# ## Multi-Layered Perceptron Model

# %% [markdown]
# The multi-layer perceptron model is also known as the Backpropagation algorithm, which executes in two stages as follows:
#
# - **Forward Stage**: Activation functions start from the input layer in the forward stage and terminate on the output layer.
#
# - **Backward Stage**: In the backward stage, weight and bias values are modified as per the model's requirement. In this stage, the error between actual output and demanded originated backward on the output layer and ended on the input layer.

# %% [markdown]
# Hence, a multi-layered perceptron model has considered as multiple artificial neural networks having various layers in which activation function does not remain linear, similar to a single layer perceptron model. Instead of linear, activation function can be executed as sigmoid, TanH, ReLU, etc., for deployment.
#
# A multi-layer perceptron model has greater processing power and can process linear and non-linear patterns. Further, it can also implement logic gates such as AND, OR, XOR, NAND, NOT, XNOR, NOR.

# %% [markdown]
# ## Basic Components of Perceptron

# %% [markdown]
# Mr. Frank Rosenblatt invented the perceptron model as a binary classifier which contains three main components. These are as follows:

# %% [markdown]
# ![perceptron-in-machine-learning2.png](attachment:f6184319-75dc-4d54-aa6e-90e0d97d9065.png)

# %% [markdown]
# - **Input Nodes or Input Layer**:

# %% [markdown]
# This is the primary component of Perceptron which accepts the initial data into the system for further processing. Each input node contains a real numerical value.

# %% [markdown]
# - **Wight and Bias:**

# %% [markdown]
# Weight parameter represents the strength of the connection between units. This is another most important parameter of Perceptron components. Weight is directly proportional to the strength of the associated input neuron in deciding the output. Further, Bias can be considered as the line of intercept in a linear equation.

# %% [markdown]
# - **Activation Function:**

# %% [markdown]
# These are the final and important components that help to determine whether the neuron will fire or not. Activation Function can be considered primarily as a step function.

# %% [markdown]
# Types of Activation functions:

# %% [markdown]
# - Sign function
#
# - Step function, and
#
# - Sigmoid function

# %% [markdown]
# ![perceptron-in-machine-learning3.png](attachment:221a9c76-a406-4a93-a6b6-62fddda54a0e.png)

# %% [markdown]
# The data scientist uses the activation function to take a subjective decision based on various problem statements and forms the desired outputs. Activation function may differ (e.g., Sign, Step, and Sigmoid) in perceptron models by checking whether the learning process is slow or has vanishing or exploding gradients.
